# %%
#TASK - 1
#SUPERVISED LEARNING

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url="http://bit.ly/w-data"
data=pd.read_csv(url)
data.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
data.isnull().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %%
data.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
sns.lineplot(x="Hours",y="Scores",data=data,color='red')
# Out:
# <AxesSubplot:xlabel='Hours', ylabel='Scores'>

# %%
x=np.array(data["Hours"]).reshape(-1,1)
y=np.array(data["Scores"])

# %%
#TRAIN AND SPLIT THE DATA

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
#LINEAR REGRESSION
# 
LR=LinearRegression()
LR.fit(x_train,y_train)
print("REGRESSION COEFFICIENT : ",LR.coef_)
print("REGRESSION INTERCEPT : ",LR.intercept_)
# Out:
# REGRESSION COEFFICIENT :  [9.94167834]
# REGRESSION INTERCEPT :  1.932204253151646

# %%
reg=(LR.coef_*x)+(LR.intercept_)
plt.scatter(x,y,color="RED")
plt.plot(x,reg,color="gold")
plt.show()

# %%
y_pred = LR.predict(x_test)
df=pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
print(df)
# Out:
#    Actual  Predicted
# 0      20  16.844722
# 1      27  33.745575
# 2      69  75.500624
# 3      30  26.786400
# 4      62  60.588106
# 5      35  39.710582
# 6      24  20.821393

# %%
hour = [[8.5]]
p_score=LR.predict(hour)
print("NO. OF STUDY HOURS : ",hour)
print("EXPECTED SCORE : ",p_score)
# Out:
# NO. OF STUDY HOURS :  [[8.5]]
# EXPECTED SCORE :  [86.43647014]

# %%
accuracy=score.score(x_test,y_test)
print("MODEL ACCURACY : ",accuracy*100)
# Out:
# MODEL ACCURACY :  93.67661043365055
